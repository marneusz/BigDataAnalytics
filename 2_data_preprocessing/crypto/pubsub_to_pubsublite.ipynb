# %%
project_number = 294601891609
project_id = "crypto-busting-374123"
location = "europe-central2"
subscription_id = "bda-coinbase-topic-sub"
topic_id = "bda-coinbase-topic"
timeout = 5.0

# %%
from concurrent.futures import TimeoutError
from google.cloud import pubsub_v1

# %%
subscriber = pubsub_v1.SubscriberClient()

# %%
subscription_path = subscriber.subscription_path(project_id, subscription_id)

# %%
messages = []

# %%
def callback(message: pubsub_v1.subscriber.message.Message) -> None:
    print(f"Received {message}.")
    message.ack()
    messages.append(message.data)

# %%
streaming_pull_future = subscriber.subscribe(subscription_path, callback=callback)
print(f"Listening for messages on {subscription_path}..\n")

with subscriber:
    try:
        # When `timeout` is not set, result() will block indefinitely,
        # unless an exception is encountered first.
        streaming_pull_future.result(timeout=timeout)
    except TimeoutError:
        streaming_pull_future.cancel()  # Trigger the shutdown.
        streaming_pull_future.result()  # Block until the shutdown is complete.
# Out:
# Listening for messages on projects/crypto-busting-374123/subscriptions/bda-coinbase-topic-sub..
#
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
# ...
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.3507","product_id":"ADA-USD"...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"1551.96","product_id":"ETH-USD...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"20895.48","product_id":"BTC-US...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"23.15","product_id":"SOL-USD",...'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'{"side":"","price":"0.0858","product_id":"DOGE-USD...'
#   ordering_key: ''
#   attributes: {}
# }.

# %%
import ast

# %%
for mes in messages:
    mes.decode('UTF-8')

# %%
response = [ast.literal_eval(mes.decode("UTF-8")) for mes in messages]
response[0]
# Out:
# {'side': '',
#  'price': '0.0858',
#  'product_id': 'DOGE-USD',
#  'time': '2023-01-15T21:33:12.111026Z'}

# %% [markdown]
# # Pub/Sub Lite

# %%
from google.cloud.pubsublite.cloudpubsub import PublisherClient
from google.cloud.pubsublite.types import (
    CloudRegion,
    CloudZone,
    MessageMetadata,
    TopicPath,
)

# %%
topic_id = "bda-coinbase-topic-lite"
subscription_id = "bda-coinbase-sub-lite"

# %%
loc = CloudRegion(location)

# %%
loc.region
# Out:
# CloudRegion(name='europe-central2')

# %%
topic_path = TopicPath(project_number, loc, topic_id)

# %%
with PublisherClient() as publisher_client:
    for msg in messages:
        api_future = publisher_client.publish(topic_path, msg)
        # result() blocks. To resolve API futures asynchronously, use add_done_callback().
        message_id = api_future.result()
        message_metadata = MessageMetadata.decode(message_id)
        print(
            f"Published a message to {topic_path} with partition {message_metadata.partition.value} and offset {message_metadata.cursor.offset}."
        )
# Out:
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3188.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3189.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3190.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3191.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3192.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3193.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3194.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3195.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3196.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3197.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3198.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3199.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3200.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3201.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3202.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3203.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3204.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3205.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3206.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3207.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3208.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3209.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3210.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3211.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3212.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3213.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3214.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3215.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3216.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3217.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3218.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3219.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3220.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3221.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3222.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3223.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3224.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3225.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3226.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3227.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3228.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3229.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3230.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3231.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3232.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3233.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3234.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3235.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3236.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3237.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3238.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3239.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3240.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3241.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3242.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3243.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3244.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3245.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3246.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3247.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3248.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3249.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3250.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3251.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3252.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3253.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3254.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3255.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3256.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3257.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3258.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3259.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3260.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3261.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3262.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3263.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3264.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3265.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3266.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3267.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3268.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3269.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3270.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3271.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3272.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3273.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3274.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3275.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3276.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3277.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3278.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3279.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3280.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3281.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3282.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3283.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3284.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3285.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3286.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3287.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3288.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3289.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3290.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3291.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3292.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3293.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3294.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3295.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3296.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3297.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3298.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3299.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3300.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3301.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3302.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3303.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3304.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3305.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3306.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3307.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3308.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3309.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3310.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3311.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3312.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3313.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3314.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3315.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3316.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3317.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3318.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3319.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3320.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3321.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3322.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3323.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3324.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3325.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3326.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3327.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3328.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3329.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3330.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3331.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3332.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3333.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3334.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3335.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3336.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3337.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3338.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3339.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3340.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3341.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3342.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3343.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3344.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3345.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3346.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3347.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3348.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3349.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3350.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3351.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3352.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3353.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3354.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3355.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3356.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3357.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3358.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3359.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3360.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3361.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3362.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3363.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3364.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3365.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3366.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3367.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3368.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3369.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3370.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3371.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3372.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3373.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3374.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3375.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3376.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3377.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3378.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3379.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3380.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3381.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3382.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3383.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3384.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3385.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3386.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3387.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3388.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3389.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3390.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3391.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3392.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3393.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3394.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3395.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3396.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3397.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3398.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3399.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3400.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3401.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3402.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3403.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3404.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3405.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3406.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3407.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3408.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3409.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3410.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3411.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3412.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3413.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3414.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3415.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3416.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3417.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3418.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3419.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3420.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3421.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3422.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3423.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3424.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3425.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3426.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3427.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3428.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3429.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3430.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3431.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3432.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3433.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3434.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3435.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3436.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3437.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3438.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3439.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3440.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3441.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3442.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3443.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3444.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3445.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3446.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3447.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3448.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3449.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3450.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3451.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3452.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3453.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3454.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3455.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3456.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3457.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3458.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3459.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3460.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3461.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3462.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3463.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3464.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3465.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3466.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3467.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3468.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3469.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3470.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3471.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3472.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3473.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3474.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3475.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3476.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3477.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3478.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3479.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3480.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3481.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3482.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3483.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3484.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3485.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3486.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3487.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3488.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3489.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3490.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3491.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3492.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3493.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3494.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3495.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3496.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3497.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3498.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3499.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3500.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3501.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3502.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3503.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3504.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3505.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3506.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3507.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3508.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3509.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3510.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3511.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3512.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3513.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3514.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3515.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3516.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3517.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3518.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3519.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3520.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3521.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3522.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3523.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3524.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3525.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3526.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3527.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3528.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3529.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3530.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3531.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3532.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3533.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3534.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3535.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3536.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3537.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3538.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 3539.
# ...
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4912.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4913.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4914.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4915.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4916.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4917.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4918.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4919.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4920.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4921.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4922.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4923.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4924.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4925.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4926.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4927.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4928.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4929.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4930.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4931.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4932.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4933.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4934.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4935.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4936.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4937.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4938.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4939.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4940.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4941.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4942.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4943.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4944.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4945.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4946.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4947.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4948.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4949.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4950.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4951.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4952.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4953.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4954.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4955.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4956.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4957.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4958.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4959.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4960.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4961.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4962.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4963.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4964.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4965.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4966.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4967.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4968.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4969.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4970.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4971.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4972.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4973.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4974.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4975.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4976.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4977.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4978.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4979.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4980.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4981.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4982.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4983.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4984.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4985.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4986.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4987.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4988.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4989.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4990.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4991.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4992.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4993.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4994.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4995.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4996.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4997.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4998.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 4999.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5000.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5001.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5002.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5003.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5004.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5005.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5006.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5007.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5008.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5009.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5010.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5011.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5012.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5013.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5014.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5015.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5016.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5017.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5018.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5019.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5020.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5021.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5022.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5023.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5024.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5025.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5026.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5027.
# Published a message to projects/294601891609/locations/europe-central2/topics/bda-coinbase-topic-lite with partition 0 and offset 5028.

# %% [markdown]
# # Pub/Sub Lite to SparkStreaming

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StringType

# %%
spark = SparkSession.builder.appName("Read Pub/Sub Stream").master("yarn").getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/01/15 23:28:03 INFO org.apache.spark.SparkEnv: Registering MapOutputTracker
# 23/01/15 23:28:03 INFO org.apache.spark.SparkEnv: Registering BlockManagerMaster
# 23/01/15 23:28:03 INFO org.apache.spark.SparkEnv: Registering BlockManagerMasterHeartbeat
# 23/01/15 23:28:03 INFO org.apache.spark.SparkEnv: Registering OutputCommitCoordinator

# %%
spark.sql('add jar file:////home/bda_reddit/dependancies/spark-streaming-pubsub_2.11.jar')
spark.sql('add jar file:////home/bda_reddit/dependancies/spark-streaming_2.13-3.3.1.jar')
spark.sql('add jar file:////home/bda_reddit/repos/BigDataAnalytics/2_data_preprocessing/pubsublite-spark-sql-streaming-0.4.2.jar')
spark.sql('add jar file:////home/bda_reddit/dependancies/spark-catalyst_2.13-3.3.1.jar')
# Out:
# 23/01/15 23:38:57 WARN org.apache.spark.SparkContext: The jar file:////home/bda_reddit/dependancies/spark-streaming-pubsub_2.11.jar has been added already. Overwriting of added jars is not supported in the current version.
# 23/01/15 23:38:57 WARN org.apache.spark.SparkContext: The jar file:////home/bda_reddit/dependancies/spark-streaming_2.13-3.3.1.jar has been added already. Overwriting of added jars is not supported in the current version.
# 23/01/15 23:38:57 WARN org.apache.spark.SparkContext: The jar file:////home/bda_reddit/repos/BigDataAnalytics/2_data_preprocessing/pubsublite-spark-sql-streaming-0.4.2.jar has been added already. Overwriting of added jars is not supported in the current version.
# DataFrame[result: int]

# %%
spark.sql("add jar file:////home/bda_reddit/dependancies/gax-grpc-1.53.1.jar")
# Out:
# 23/01/15 23:33:12 WARN org.apache.spark.SparkContext: The jar file:////home/bda_reddit/dependancies/gax-grpc-1.53.1.jar has been added already. Overwriting of added jars is not supported in the current version.
# DataFrame[result: int]

# %%
sdf = (
    spark.readStream.format("pubsublite")
    .option(
        "pubsublite.subscription",
        f"projects/{project_number}/locations/{location}/subscriptions/{subscription_id}",
    )
    .load()
)

# %%
sdf.writeStream.format("console").start()
# Out:
# 23/01/15 23:39:03 WARN org.apache.spark.sql.streaming.StreamingQueryManager: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-6b4a85a2-1cc0-4062-b5c7-be0af51a5825. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 23/01/15 23:39:03 WARN org.apache.spark.sql.streaming.StreamingQueryManager: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 23/01/15 23:39:04 ERROR org.apache.spark.sql.execution.streaming.MicroBatchExecution: Query [id = c149575b-da6e-404d-beb9-d3eaef8d1463, runId = 4b5d0352-f21d-464a-847e-068a1ba6dc92] terminated with error
# java.lang.NoClassDefFoundError: com/google/api/gax/rpc/ApiException
# 	at com.google.cloud.pubsublite.spark.PslTable.newScanBuilder(PslTable.java:33)
# 	at org.apache.spark.sql.execution.streaming.MicroBatchExecution$$anonfun$1.$anonfun$applyOrElse$4(MicroBatchExecution.scala:103)
# 	at scala.collection.mutable.HashMap.getOrElseUpdate(HashMap.scala:86)
# 	at org.apache.spark.sql.execution.streaming.MicroBatchExecution$$anonfun$1.applyOrElse(MicroBatchExecution.scala:97)
# 	at org.apache.spark.sql.execution.streaming.MicroBatchExecution$$anonfun$1.applyOrElse(MicroBatchExecution.scala:82)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$transformDown$1(TreeNode.scala:318)
# 	at org.apache.spark.sql.catalyst.trees.CurrentOrigin$.withOrigin(TreeNode.scala:74)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformDown(TreeNode.scala:318)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.org$apache$spark$sql$catalyst$plans$logical$AnalysisHelper$$super$transformDown(LogicalPlan.scala:29)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDown(AnalysisHelper.scala:173)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDown$(AnalysisHelper.scala:171)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDown(LogicalPlan.scala:29)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDown(LogicalPlan.scala:29)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transform(TreeNode.scala:307)
# 	at org.apache.spark.sql.execution.streaming.MicroBatchExecution.logicalPlan$lzycompute(MicroBatchExecution.scala:82)
# 	at org.apache.spark.sql.execution.streaming.MicroBatchExecution.logicalPlan(MicroBatchExecution.scala:62)
# 	at org.apache.spark.sql.execution.streaming.StreamExecution.$anonfun$runStream$1(StreamExecution.scala:326)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:775)
# 	at org.apache.spark.sql.execution.streaming.StreamExecution.org$apache$spark$sql$execution$streaming$StreamExecution$$runStream(StreamExecution.scala:317)
# 	at org.apache.spark.sql.execution.streaming.StreamExecution$$anon$1.run(StreamExecution.scala:244)
# Caused by: java.lang.ClassNotFoundException: com.google.api.gax.rpc.ApiException
# 	at java.net.URLClassLoader.findClass(URLClassLoader.java:387)
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:418)
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:351)
# 	... 21 more
# Exception in thread "stream execution thread for [id = c149575b-da6e-404d-beb9-d3eaef8d1463, runId = 4b5d0352-f21d-464a-847e-068a1ba6dc92]" java.lang.NoClassDefFoundError: com/google/api/gax/rpc/ApiException
# 	at com.google.cloud.pubsublite.spark.PslTable.newScanBuilder(PslTable.java:33)
# 	at org.apache.spark.sql.execution.streaming.MicroBatchExecution$$anonfun$1.$anonfun$applyOrElse$4(MicroBatchExecution.scala:103)
# 	at scala.collection.mutable.HashMap.getOrElseUpdate(HashMap.scala:86)
# 	at org.apache.spark.sql.execution.streaming.MicroBatchExecution$$anonfun$1.applyOrElse(MicroBatchExecution.scala:97)
# 	at org.apache.spark.sql.execution.streaming.MicroBatchExecution$$anonfun$1.applyOrElse(MicroBatchExecution.scala:82)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$transformDown$1(TreeNode.scala:318)
# 	at org.apache.spark.sql.catalyst.trees.CurrentOrigin$.withOrigin(TreeNode.scala:74)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformDown(TreeNode.scala:318)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.org$apache$spark$sql$catalyst$plans$logical$AnalysisHelper$$super$transformDown(LogicalPlan.scala:29)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDown(AnalysisHelper.scala:173)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDown$(AnalysisHelper.scala:171)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDown(LogicalPlan.scala:29)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDown(LogicalPlan.scala:29)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transform(TreeNode.scala:307)
# 	at org.apache.spark.sql.execution.streaming.MicroBatchExecution.logicalPlan$lzycompute(MicroBatchExecution.scala:82)
# 	at org.apache.spark.sql.execution.streaming.MicroBatchExecution.logicalPlan(MicroBatchExecution.scala:62)
# 	at org.apache.spark.sql.execution.streaming.StreamExecution.$anonfun$runStream$1(StreamExecution.scala:326)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:775)
# 	at org.apache.spark.sql.execution.streaming.StreamExecution.org$apache$spark$sql$execution$streaming$StreamExecution$$runStream(StreamExecution.scala:317)
# 	at org.apache.spark.sql.execution.streaming.StreamExecution$$anon$1.run(StreamExecution.scala:244)
# Caused by: java.lang.ClassNotFoundException: com.google.api.gax.rpc.ApiException
# 	at java.net.URLClassLoader.findClass(URLClassLoader.java:387)
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:418)
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:351)
# 	... 21 more

# %%
query = sdf.writeStream.format("console").outputMode("append").start().awaitTermination()
# Out:
# 23/01/15 23:34:35 WARN org.apache.spark.sql.streaming.StreamingQueryManager: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-6306b912-13ee-4f74-b1b5-d41dd285ccfc. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 23/01/15 23:34:35 WARN org.apache.spark.sql.streaming.StreamingQueryManager: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 23/01/15 23:34:36 ERROR org.apache.spark.sql.execution.streaming.MicroBatchExecution: Query [id = 5f2e1f9c-3874-4ebc-947d-0e205b866d47, runId = 32bccd49-734e-4ae2-a647-b4b468d85e24] terminated with error
# java.lang.NoClassDefFoundError: com/google/api/gax/rpc/ApiException
# 	at com.google.cloud.pubsublite.spark.PslTable.newScanBuilder(PslTable.java:33)
# 	at org.apache.spark.sql.execution.streaming.MicroBatchExecution$$anonfun$1.$anonfun$applyOrElse$4(MicroBatchExecution.scala:103)
# 	at scala.collection.mutable.HashMap.getOrElseUpdate(HashMap.scala:86)
# 	at org.apache.spark.sql.execution.streaming.MicroBatchExecution$$anonfun$1.applyOrElse(MicroBatchExecution.scala:97)
# 	at org.apache.spark.sql.execution.streaming.MicroBatchExecution$$anonfun$1.applyOrElse(MicroBatchExecution.scala:82)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$transformDown$1(TreeNode.scala:318)
# 	at org.apache.spark.sql.catalyst.trees.CurrentOrigin$.withOrigin(TreeNode.scala:74)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformDown(TreeNode.scala:318)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.org$apache$spark$sql$catalyst$plans$logical$AnalysisHelper$$super$transformDown(LogicalPlan.scala:29)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDown(AnalysisHelper.scala:173)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDown$(AnalysisHelper.scala:171)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDown(LogicalPlan.scala:29)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDown(LogicalPlan.scala:29)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transform(TreeNode.scala:307)
# 	at org.apache.spark.sql.execution.streaming.MicroBatchExecution.logicalPlan$lzycompute(MicroBatchExecution.scala:82)
# 	at org.apache.spark.sql.execution.streaming.MicroBatchExecution.logicalPlan(MicroBatchExecution.scala:62)
# 	at org.apache.spark.sql.execution.streaming.StreamExecution.$anonfun$runStream$1(StreamExecution.scala:326)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:775)
# 	at org.apache.spark.sql.execution.streaming.StreamExecution.org$apache$spark$sql$execution$streaming$StreamExecution$$runStream(StreamExecution.scala:317)
# 	at org.apache.spark.sql.execution.streaming.StreamExecution$$anon$1.run(StreamExecution.scala:244)
# Caused by: java.lang.ClassNotFoundException: com.google.api.gax.rpc.ApiException
# 	at java.net.URLClassLoader.findClass(URLClassLoader.java:387)
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:418)
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:351)
# 	... 21 more
# Exception in thread "stream execution thread for [id = 5f2e1f9c-3874-4ebc-947d-0e205b866d47, runId = 32bccd49-734e-4ae2-a647-b4b468d85e24]" java.lang.NoClassDefFoundError: com/google/api/gax/rpc/ApiException
# 	at com.google.cloud.pubsublite.spark.PslTable.newScanBuilder(PslTable.java:33)
# 	at org.apache.spark.sql.execution.streaming.MicroBatchExecution$$anonfun$1.$anonfun$applyOrElse$4(MicroBatchExecution.scala:103)
# 	at scala.collection.mutable.HashMap.getOrElseUpdate(HashMap.scala:86)
# 	at org.apache.spark.sql.execution.streaming.MicroBatchExecution$$anonfun$1.applyOrElse(MicroBatchExecution.scala:97)
# 	at org.apache.spark.sql.execution.streaming.MicroBatchExecution$$anonfun$1.applyOrElse(MicroBatchExecution.scala:82)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$transformDown$1(TreeNode.scala:318)
# 	at org.apache.spark.sql.catalyst.trees.CurrentOrigin$.withOrigin(TreeNode.scala:74)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformDown(TreeNode.scala:318)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.org$apache$spark$sql$catalyst$plans$logical$AnalysisHelper$$super$transformDown(LogicalPlan.scala:29)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDown(AnalysisHelper.scala:173)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDown$(AnalysisHelper.scala:171)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDown(LogicalPlan.scala:29)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDown(LogicalPlan.scala:29)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transform(TreeNode.scala:307)
# 	at org.apache.spark.sql.execution.streaming.MicroBatchExecution.logicalPlan$lzycompute(MicroBatchExecution.scala:82)
# 	at org.apache.spark.sql.execution.streaming.MicroBatchExecution.logicalPlan(MicroBatchExecution.scala:62)
# 	at org.apache.spark.sql.execution.streaming.StreamExecution.$anonfun$runStream$1(StreamExecution.scala:326)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:775)
# 	at org.apache.spark.sql.execution.streaming.StreamExecution.org$apache$spark$sql$execution$streaming$StreamExecution$$runStream(StreamExecution.scala:317)
# 	at org.apache.spark.sql.execution.streaming.StreamExecution$$anon$1.run(StreamExecution.scala:244)
# Caused by: java.lang.ClassNotFoundException: com.google.api.gax.rpc.ApiException
# 	at java.net.URLClassLoader.findClass(URLClassLoader.java:387)
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:418)
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:351)
# 	... 21 more
# ---------------------------------------------------------------------------
# StreamingQueryException                   Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 query = sdf.writeStream.format("console").outputMode("append").start().awaitTermination()
#
# File /usr/lib/spark/python/pyspark/sql/streaming.py:101, in StreamingQuery.awaitTermination(self, timeout)
#      99     return self._jsq.awaitTermination(int(timeout * 1000))
#     100 else:
# --> 101     return self._jsq.awaitTermination()
#
# File /opt/conda/miniconda3/lib/python3.8/site-packages/py4j/java_gateway.py:1304, in JavaMember.__call__(self, *args)
#    1298 command = proto.CALL_COMMAND_NAME +\
#    1299     self.command_header +\
#    1300     args_command +\
#    1301     proto.END_COMMAND_PART
#    1303 answer = self.gateway_client.send_command(command)
# -> 1304 return_value = get_return_value(
#    1305     answer, self.gateway_client, self.target_id, self.name)
#    1307 for temp_arg in temp_args:
#    1308     temp_arg._detach()
#
# File /usr/lib/spark/python/pyspark/sql/utils.py:117, in capture_sql_exception.<locals>.deco(*a, **kw)
#     113 converted = convert_exception(e.java_exception)
#     114 if not isinstance(converted, UnknownException):
#     115     # Hide where the exception came from that shows a non-Pythonic
#     116     # JVM exception message.
# --> 117     raise converted from None
#     118 else:
#     119     raise
#
# StreamingQueryException: com/google/api/gax/rpc/ApiException
# === Streaming Query ===
# Identifier: [id = 5f2e1f9c-3874-4ebc-947d-0e205b866d47, runId = 32bccd49-734e-4ae2-a647-b4b468d85e24]
# Current Committed Offsets: {}
# Current Available Offsets: {}
#
# Current State: INITIALIZING
# Thread State: RUNNABLE
